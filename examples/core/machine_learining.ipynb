# %% [markdown]
# # Machine Learning examples with interpreTS

# %% [markdown]
# This notebook shows more training models usuing interpreTS in version 0.4.1

# %%
import pandas as pd
import numpy as np
import interpreTS as it
from sktime.datasets import load_airline
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %% [markdown]
# ### Regression with interpreTS and Multiple ML Models

# %%
# Load dataset
data = load_airline()
data = data.reset_index()
data.columns = ["timestamp", "passengers"]
data["timestamp"] = data["timestamp"].dt.to_timestamp()
data.set_index("timestamp", inplace=True)

# %%
print(data.head())
# Out:
#             passengers
# timestamp
# 1949-01-01       112.0
# 1949-02-01       118.0
# 1949-03-01       132.0
# 1949-04-01       129.0
# 1949-05-01       121.0

# %%
# Add time-based features
data["year"] = data.index.year
data["month"] = data.index.month
data["adjusted_month"] = (data["year"] - data["year"].min()) * 12 + data["month"]
print(data.head())
# Out:
#             passengers  year  month  adjusted_month
# timestamp
# 1949-01-01       112.0  1949      1               1
# 1949-02-01       118.0  1949      2               2
# 1949-03-01       132.0  1949      3               3
# 1949-04-01       129.0  1949      4               4
# 1949-05-01       121.0  1949      5               5

# %%
# Add lagged target variable
data["target"] = data["passengers"].shift(-12)  # Predict passengers 12 months ahead
data = data.dropna()
print(data)
# Out:
#             passengers  year  month  adjusted_month  target
# timestamp
# 1949-01-01       112.0  1949      1               1   115.0
# 1949-02-01       118.0  1949      2               2   126.0
# 1949-03-01       132.0  1949      3               3   141.0
# 1949-04-01       129.0  1949      4               4   135.0
# 1949-05-01       121.0  1949      5               5   125.0
# ...                ...   ...    ...             ...     ...
# 1959-08-01       559.0  1959      8             128   606.0
# 1959-09-01       463.0  1959      9             129   508.0
# 1959-10-01       407.0  1959     10             130   461.0
# 1959-11-01       362.0  1959     11             131   390.0
# 1959-12-01       405.0  1959     12             132   432.0
#
# [132 rows x 5 columns]

# %% [markdown]
# ----------------------------------------------

# %%
# Feature extraction
extractor = it.FeatureExtractor(
    id_column="adjusted_month",
    features=[
        it.Features.MEAN,
        it.Features.VARIANCE,
        it.Features.ENTROPY,
        it.Features.SPIKENESS,
        it.Features.TREND_STRENGTH,
        it.Features.SEASONALITY_STRENGTH,
        it.Features.LINEARITY,
        it.Features.ABSOLUTE_ENERGY,
        it.Features.MEAN_CHANGE,
    ],
)

# %%
# Extract features for the full dataset
numeric_columns = data.select_dtypes(include=["number"]).columns
data_numeric = data[numeric_columns]
features = extractor.extract_features(data_numeric, mode="sequential")

# %%
print(features)
# Out:
#    mean_passengers  mean_year  mean_month  mean_target  variance_passengers  \
# 0       262.492424     1954.0         6.5   294.265152         11369.061011
#
#    variance_year  variance_month  variance_target  entropy_passengers  \
# 0      10.076336       12.007634     13335.814654            0.964481
#
#    entropy_year  ...  linearity_month  linearity_target  \
# 0      0.998999  ...              0.0           0.00025
#
#    absolute_energy_passengers  absolute_energy_year  absolute_energy_month  \
# 0                  10584447.0             503992632                   7150
#
#    absolute_energy_target                             mean_change_passengers  \
# 0              13177133.0  timestamp
# 1949-01-01     NaN
# 1949-02-01     Na...
#
#                                     mean_change_year  \
# 0  timestamp
# 1949-01-01    NaN
# 1949-02-01    NaN
# ...
#
#                                    mean_change_month  \
# 0  timestamp
# 1949-01-01    NaN
# 1949-02-01    NaN
# ...
#
#                                   mean_change_target
# 0  timestamp
# 1949-01-01     NaN
# 1949-02-01     Na...
#
# [1 rows x 36 columns]

# %%
#Maping columns name
try:
    feature_columns = [f"{feature}_series" for feature in extractor.features]
    features_df = pd.DataFrame(features, columns=feature_columns)
except ValueError as e:
    print("Błąd mapowania nazw kolumn:", e)
    # Debug: Wyświetlenie rozmiaru danych i wymaganych nazw kolumn
    print(f"Rozmiar danych: {features.shape}, liczba kolumn: {len(extractor.features)}")

# %%
print(feature_columns)
# Out:
# ['mean_series', 'variance_series', 'entropy_series', 'spikeness_series', 'trend_strength_series', 'seasonality_strength_series', 'linearity_series', 'absolute_energy_series', 'mean_change_series']

# %%
print(features_df)
# Out:
#    mean_series  variance_series  entropy_series  spikeness_series  \
# 0          NaN              NaN             NaN               NaN
#
#    trend_strength_series  seasonality_strength_series  linearity_series  \
# 0                    NaN                          NaN               NaN
#
#    absolute_energy_series  mean_change_series
# 0                     NaN                 NaN

# %%
scaler = StandardScaler()
try:
    features_scaled = scaler.fit_transform(features)
except ValueError as e:
    print("Błąd skalowania:", e)
# Out:
# Błąd skalowania: setting an array element with a sequence.

# %%
test_pct = 0.2
split_index = int(len(features) * (1 - test_pct))
features_train, features_test = features[:split_index], features[split_index:]
train_y, test_y = data["target"].iloc[:split_index].reset_index(drop=True), data["target"].iloc[split_index:].reset_index(drop=True)

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Random Forest": RandomForestRegressor(random_state=42),
    "Support Vector Regression": SVR(kernel="rbf"),
    "XGBoost": XGBRegressor(random_state=42),
}

# %%
results = {}
for model_name, model in models.items():
    try:
        model.fit(features_train, train_y)
        predictions = model.predict(features_test)
        rmse = np.sqrt(mean_squared_error(test_y, predictions))
        results[model_name] = rmse
    except ValueError as e:
        print(f"Błąd podczas trenowania modelu {model_name}:", e)

print("Wyniki RMSE:")
for model, rmse in results.items():
    print(f"{model}: {rmse:.4f}")
# Out:
# Błąd podczas trenowania modelu Linear Regression: Found array with 0 sample(s) (shape=(0, 36)) while a minimum of 1 is required by LinearRegression.
# Błąd podczas trenowania modelu Random Forest: Found array with 0 sample(s) (shape=(0, 36)) while a minimum of 1 is required by RandomForestRegressor.
# Błąd podczas trenowania modelu Support Vector Regression: Found array with 0 sample(s) (shape=(0, 36)) while a minimum of 1 is required by SVR.
# Błąd podczas trenowania modelu XGBoost: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, the experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:mean_change_passengers: object, mean_change_year: object, mean_change_month: object, mean_change_target: object
# Wyniki RMSE:

# %%
import pandas as pd
import numpy as np
import interpreTS as it

# Minimalny zestaw danych
df_test = pd.DataFrame({
    "adjusted_month": [1, 1, 1, 2, 2, 2],
    "value": [10, 20, 30, 40, 50, 60]
})

# Tworzenie obiektu FeatureExtractor
extractor = it.FeatureExtractor(id_column="adjusted_month", features=[
    it.Features.MEAN,
    it.Features.VARIANCE,
    it.Features.ENTROPY
])

# Wywołanie extract_features
features = extractor.extract_features(df_test)

print(features)
# Out:
#    mean_value  variance_value  entropy_value
# 0        35.0           350.0        0.99857

# %%
print(data_numeric.info())
print(data_numeric.head())
print(data_numeric.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 132 entries, 1949-01-01 to 1959-12-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      132 non-null    float64
#  1   year            132 non-null    int32
#  2   month           132 non-null    int32
#  3   adjusted_month  132 non-null    int32
#  4   target          132 non-null    float64
# dtypes: float64(2), int32(3)
# memory usage: 4.6 KB
# None
#             passengers  year  month  adjusted_month  target
# timestamp
# 1949-01-01       112.0  1949      1               1   115.0
# 1949-02-01       118.0  1949      2               2   126.0
# 1949-03-01       132.0  1949      3               3   141.0
# 1949-04-01       129.0  1949      4               4   135.0
# 1949-05-01       121.0  1949      5               5   125.0
# passengers        0
# year              0
# month             0
# adjusted_month    0
# target            0
# dtype: int64

# %%
print(data_numeric.groupby("adjusted_month").size())
# Out:
# adjusted_month
# 1      1
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 128    1
# 129    1
# 130    1
# 131    1
# 132    1
# Length: 132, dtype: int64

# %%
extractor = it.FeatureExtractor(
    id_column="adjusted_month",
    features=[
        it.Features.MEAN,
        it.Features.VARIANCE,
        it.Features.ENTROPY,
    ],
)
features = extractor.extract_features(data_numeric)
print(features)
# Out:
#    mean_passengers  mean_year  mean_month  mean_target  variance_passengers  \
# 0       262.492424     1954.0         6.5   294.265152         11369.061011
#
#    variance_year  variance_month  variance_target  entropy_passengers  \
# 0      10.076336       12.007634     13335.814654            0.964481
#
#    entropy_year  entropy_month  entropy_target
# 0      0.998999       0.998891        0.962286

# %%
# Wnioski
# adjusted_month zostało użyte jako id_column, ale liczba unikalnych wartości to 132 (każdy wiersz ma swoją unikalną wartość). To prowadzi do sytuacji, w której każda grupa ma dokładnie jeden wiersz.
# ENTROPY może być źle interpretowana, jeśli dane nie mają wystarczającej liczby różnych wartości w grupie.
# Kod nie zgłasza błędów ani ostrzeżeń, mimo że dane wejściowe nie pasują do logiki działania funkcji. To może prowadzić do mylnych interpretacji wyników, a tu np wybrane id_column nie ma sensu, można dodać coś do sparwdzania wyboru id_column
#

# %%
# Grup by month
data_numeric["group_month"] = data_numeric.index.month

extractor = it.FeatureExtractor(
    id_column="group_month",
    features=[
        it.Features.MEAN,
        it.Features.VARIANCE,
        it.Features.ENTROPY,
    ],
)
features = extractor.extract_features(data_numeric)
print(features)
# Out:
#    mean_passengers  mean_year  mean_month  mean_adjusted_month  mean_target  \
# 0       262.492424     1954.0         6.5                 66.5   294.265152
#
#    variance_passengers  variance_year  variance_month  \
# 0         11369.061011      10.076336       12.007634
#
#    variance_adjusted_month  variance_target  entropy_passengers  entropy_year  \
# 0                   1463.0     13335.814654            0.964481      0.998999
#
#    entropy_month  entropy_adjusted_month  entropy_target
# 0       0.998891                0.997381        0.962286

# %%
data_uniform = data_numeric.copy()
data_uniform["passengers"] = 100  # the same values

extractor = it.FeatureExtractor(
    id_column="year",  # Grup by year
    features=[
        it.Features.MEAN,
        it.Features.VARIANCE,
        it.Features.ENTROPY,
    ],
)
features = extractor.extract_features(data_uniform)
print(features)
# Out:
#    mean_passengers  mean_month  mean_adjusted_month  mean_target  \
# 0            100.0         6.5                 66.5   294.265152
#
#    mean_group_month  variance_passengers  variance_month  \
# 0               6.5                  0.0       12.007634
#
#    variance_adjusted_month  variance_target  variance_group_month  \
# 0                   1463.0     13335.814654             12.007634
#
#    entropy_passengers  entropy_month  entropy_adjusted_month  entropy_target  \
# 0                 0.0       0.998891                0.997381        0.962286
#
#    entropy_group_month
# 0             0.998891

# %%
import numpy as np

# Random data
data_random = data_numeric.copy()
data_random["passengers"] = np.random.randint(50, 200, size=len(data_random))

extractor = it.FeatureExtractor(
    id_column="month",  # Grupo by month
    features=[
        it.Features.MEAN,
        it.Features.VARIANCE,
        it.Features.ENTROPY,
    ],
)
features = extractor.extract_features(data_random)
print(features)
# Out:
#    mean_passengers  mean_year  mean_adjusted_month  mean_target  \
# 0       124.401515     1954.0                 66.5   294.265152
#
#    mean_group_month  variance_passengers  variance_year  \
# 0               6.5          1782.608547      10.076336
#
#    variance_adjusted_month  variance_target  variance_group_month  \
# 0                   1463.0     13335.814654             12.007634
#
#    entropy_passengers  entropy_year  entropy_adjusted_month  entropy_target  \
# 0            0.994492      0.998999                0.997381        0.962286
#
#    entropy_group_month
# 0             0.998891

# %%
# nan values
data_with_nan = data_numeric.copy()
data_with_nan.loc[data_with_nan.index.month == 5, "passengers"] = np.nan  

extractor = it.FeatureExtractor(
    id_column="month",
    features=[
        it.Features.MEAN,
        it.Features.VARIANCE,
        it.Features.ENTROPY,
    ],
)
features = extractor.extract_features(data_with_nan)
print(features)
# Out:
# Warning: Failed to calculate mean for column passengers: Data contains NaN values.
# Warning: Failed to calculate variance for column passengers: Data contains NaN values.
# Warning: Failed to calculate entropy for column passengers: Data contains NaN values.
#   mean_passengers  mean_year  mean_adjusted_month  mean_target  \
# 0            <NA>     1954.0                 66.5   294.265152
#
#    mean_group_month variance_passengers  variance_year  \
# 0               6.5                <NA>      10.076336
#
#    variance_adjusted_month  variance_target  variance_group_month  \
# 0                   1463.0     13335.814654             12.007634
#
#   entropy_passengers  entropy_year  entropy_adjusted_month  entropy_target  \
# 0               <NA>      0.998999                0.997381        0.962286
#
#    entropy_group_month
# 0             0.998891

# %%
# Wnioski: Wyświetlać bardziej szczegółowe komunikaty o błędach lub ostrzeżenia...
# Dodać obsługę brakujących danych: np. opcję ignorowania NaN (skipna=True) w obliczeniach.

# %%
# new features
data_extended = data_numeric.copy()
data_extended["feature_1"] = data_numeric["passengers"] * 1.1
data_extended["feature_2"] = np.log1p(data_numeric["passengers"])

extractor = it.FeatureExtractor(
    id_column="year",  # Grup by year
    features=[
        it.Features.MEAN,
        it.Features.VARIANCE,
        it.Features.ENTROPY,
    ],
)
features = extractor.extract_features(data_extended)
print(features)
# Out:
#    mean_passengers  mean_month  mean_adjusted_month  mean_target  \
# 0       262.492424         6.5                 66.5   294.265152
#
#    mean_group_month  mean_feature_1  mean_feature_2  variance_passengers  \
# 0               6.5      288.741667        5.491038         11369.061011
#
#    variance_month  variance_adjusted_month  ...  variance_group_month  \
# 0       12.007634                   1463.0  ...             12.007634
#
#    variance_feature_1  variance_feature_2  entropy_passengers  entropy_month  \
# 0        13756.563823            0.171701            0.964481       0.998891
#
#    entropy_adjusted_month  entropy_target  entropy_group_month  \
# 0                0.997381        0.962286             0.998891
#
#    entropy_feature_1  entropy_feature_2
# 0           0.964481           0.986172
#
# [1 rows x 21 columns]

# %%
# non normal type od id_column
extractor = it.FeatureExtractor(
    id_column="passengers",  
    features=[
        it.Features.MEAN,
        it.Features.VARIANCE,
        it.Features.ENTROPY,
    ],
)
features = extractor.extract_features(data_numeric)
print(features)
# Out:
#    mean_year  mean_month  mean_adjusted_month  mean_target  mean_group_month  \
# 0     1954.0         6.5                 66.5   294.265152               6.5
#
#    variance_year  variance_month  variance_adjusted_month  variance_target  \
# 0      10.076336       12.007634                   1463.0     13335.814654
#
#    variance_group_month  entropy_year  entropy_month  entropy_adjusted_month  \
# 0             12.007634      0.998999       0.998891                0.997381
#
#    entropy_target  entropy_group_month
# 0        0.962286             0.998891

# %%
# Wnioski: Brak walidacji logicznej kolumny grupującej (id_column), co może prowadzić do błędnych interpretacji wyników.

# %%
# test small data
small_data = data_numeric.head(5)

extractor = it.FeatureExtractor(
    id_column="month",
    features=[
        it.Features.MEAN,
        it.Features.VARIANCE,
        it.Features.ENTROPY,
    ],
)
features = extractor.extract_features(small_data)
print(features)
# Out:
#    mean_passengers  mean_year  mean_adjusted_month  mean_target  \
# 0            122.4     1949.0                  3.0        128.4
#
#    mean_group_month  variance_passengers  variance_year  \
# 0               3.0                 66.3            0.0
#
#    variance_adjusted_month  variance_target  variance_group_month  \
# 0                      2.5             99.8                   2.5
#
#    entropy_passengers  entropy_year  entropy_adjusted_month  entropy_target  \
# 0            0.999145           0.0                0.998799        0.997961
#
#    entropy_group_month
# 0             0.998799

# %%
# Select relevant features
selected_columns = [
    "mean_passengers", "variance_passengers", "entropy_passengers",
    "spikeness_passengers", "trend_strength_passengers"
]
features = pd.DataFrame(features)[selected_columns]

# Verify extracted features
print(features)
# Out:
#    mean_passengers  variance_passengers  entropy_passengers  \
# 0       262.492424         11369.061011            0.964481
#
#    spikeness_passengers  trend_strength_passengers
# 0              0.570796                   0.845783

# %%
# Scale features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)
print(features_scaled)
# Out:
# [[0. 0. 0. 0. 0.]]

# %%
# Ensure target variable matches features
data = data.iloc[:len(features)]

# %%
# Train/test split (AFTER feature extraction)
test_pct = 0.2
split_index = int(len(features) * (1 - test_pct))
features_train, features_test = features[:split_index], features[split_index:]
train_y, test_y = data["target"].iloc[:split_index].reset_index(drop=True), data["target"].iloc[split_index:].reset_index(drop=True)

# %%
print(train_y)
# Out:
# Series([], Name: target, dtype: float64)

# %%
# Results of tests: ...

# %% [markdown]
# --------------------------------------------------------

# %%
# Define sliding window for feature extraction
window_size = 12  # 12 months (one year)
sequences = []

# %%
# Create sliding windows
for start_idx in range(len(data) - window_size + 1):
    window = data.iloc[start_idx:start_idx + window_size].copy()
    sequences.append(window)

# %%
# Extract features
extractor = it.FeatureExtractor(
    id_column="adjusted_month",
    features=[
        it.Features.MEAN,
        it.Features.VARIANCE,
        it.Features.ENTROPY,
        it.Features.SPIKENESS,
        it.Features.TREND_STRENGTH,
        it.Features.SEASONALITY_STRENGTH,
        it.Features.LINEARITY,
        it.Features.ABSOLUTE_ENERGY,
        it.Features.MEAN_CHANGE,
    ],
)

# %%
# Extract features from each sequence
extracted_features = []
for sequence in sequences:
    numeric_columns = sequence.select_dtypes(include=["number"]).columns
    sequence_numeric = sequence[numeric_columns]
    features = extractor.extract_features(sequence_numeric, mode="sequential")
    extracted_features.append(features)

# Flatten extracted_features to ensure it's 2D
extracted_features_flattened = np.vstack(extracted_features)

# %%
print("Shape of extracted features:", extracted_features_flattened.shape)
print("Number of features in extractor:", len(extractor.features))
# Out:
# Shape of extracted features: (121, 36)
# Number of features in extractor: 9

# %%
# Verify the shape of extracted features
print("Shape of extracted features:", extracted_features_flattened.shape)

# Dynamically generate column names to match the data shape
feature_columns = [f"feature_{i}" for i in range(extracted_features_flattened.shape[1])]

# Create DataFrame with dynamically generated column names
features = pd.DataFrame(extracted_features_flattened, columns=feature_columns)

# Verify the DataFrame
print(features.head())
# Out:
# Shape of extracted features: (121, 36)
#     feature_0    feature_1 feature_2   feature_3   feature_4 feature_5  \
# 0  126.666667       1949.0       6.5  139.666667  188.242424       0.0
# 1  126.916667  1949.083333       6.5  142.166667  180.992424  0.083333
# 2  127.583333  1949.166667       6.5  144.166667  173.356061  0.151515
# 3  128.333333      1949.25       6.5      147.25  187.333333  0.204545
# 4  128.833333  1949.333333       6.5  149.583333  191.060606  0.242424
#
#   feature_6   feature_7 feature_8 feature_9  ... feature_26 feature_27  \
# 0      13.0   363.69697   0.99429       0.0  ...        0.0   0.059659
# 1      13.0  304.151515  0.992977  0.841106  ...       0.25   0.018318
# 2      13.0  281.606061  0.990952   0.92805  ...       0.16   0.000775
# 3      13.0  374.386364  0.993914  0.966266  ...       0.09    0.03121
# 4      13.0  377.356061  0.994544  0.984764  ...       0.04    0.01088
#
#   feature_28 feature_29 feature_30 feature_31  \
# 0   194604.0   45583212        650   238082.0
# 1   195285.0   45587111        650   245882.0
# 2   197237.0   45591010        650   252506.0
# 3   199694.0   45594909        650   264309.0
# 4   201278.0   45598808        650   272653.0
#
#                                           feature_32  \
# 0  timestamp
# 1949-01-01    NaN
# 1949-02-01    NaN
# ...
# 1  timestamp
# 1949-02-01    NaN
# 1949-03-01    NaN
# ...
# 2  timestamp
# 1949-03-01    NaN
# 1949-04-01    NaN
# ...
# 3  timestamp
# 1949-04-01    NaN
# 1949-05-01    NaN
# ...
# 4  timestamp
# 1949-05-01    NaN
# 1949-06-01    NaN
# ...
#
#                                           feature_33  \
# 0  timestamp
# 1949-01-01    NaN
# 1949-02-01    NaN
# ...
# 1  timestamp
# 1949-02-01    NaN
# 1949-03-01    NaN
# ...
# 2  timestamp
# 1949-03-01    NaN
# 1949-04-01    NaN
# ...
# 3  timestamp
# 1949-04-01    NaN
# 1949-05-01    NaN
# ...
# 4  timestamp
# 1949-05-01    NaN
# 1949-06-01    NaN
# ...
#
#                                           feature_34  \
# 0  timestamp
# 1949-01-01    NaN
# 1949-02-01    NaN
# ...
# 1  timestamp
# 1949-02-01    NaN
# 1949-03-01    NaN
# ...
# 2  timestamp
# 1949-03-01    NaN
# 1949-04-01    NaN
# ...
# 3  timestamp
# 1949-04-01    NaN
# 1949-05-01    NaN
# ...
# 4  timestamp
# 1949-05-01    NaN
# 1949-06-01    NaN
# ...
#
#                                           feature_35
# 0  timestamp
# 1949-01-01    NaN
# 1949-02-01    NaN
# ...
# 1  timestamp
# 1949-02-01    NaN
# 1949-03-01    NaN
# ...
# 2  timestamp
# 1949-03-01    NaN
# 1949-04-01    NaN
# ...
# 3  timestamp
# 1949-04-01    NaN
# 1949-05-01    NaN
# ...
# 4  timestamp
# 1949-05-01    NaN
# 1949-06-01    NaN
# ...
#
# [5 rows x 36 columns]

# %%
print(extracted_features_flattened)
# Out:
# [[126.66666666666667 1949.0 6.5 ... timestamp
#                                     1949-01-01    NaN
#                                     1949-02-01    NaN
#                                     1949-03-01    NaN
#                                     1949-04-01    NaN
#                                     1949-05-01    NaN
#                                     1949-06-01    0.0
#                                     1949-07-01    0.0
#                                     1949-08-01    0.0
#                                     1949-09-01    0.0
#                                     1949-10-01    0.0
#                                     1949-11-01    0.0
#                                     1949-12-01    0.0
#                                     Name: year, dtype: float64
#   timestamp
#   1949-01-01    NaN
#   1949-02-01    NaN
#   1949-03-01    NaN
#   1949-04-01    NaN
#   1949-05-01    NaN
#   1949-06-01    1.0
#   1949-07-01    1.0
#   1949-08-01    1.0
#   1949-09-01    1.0
#   1949-10-01    1.0
#   1949-11-01    1.0
#   1949-12-01    1.0
#   Name: month, dtype: float64 timestamp
#                               1949-01-01    NaN
#                               1949-02-01    NaN
#                               1949-03-01    NaN
#                               1949-04-01    NaN
#                               1949-05-01    NaN
#                               1949-06-01    6.8
#                               1949-07-01    8.8
#                               1949-08-01    5.8
#                               1949-09-01    4.6
#                               1949-10-01    1.6
#                               1949-11-01   -7.0
#                               1949-12-01   -6.0
#                               Name: target, dtype: float64]
#  [126.91666666666667 1949.0833333333333 6.5 ...
#   timestamp
#   1949-02-01    NaN
#   1949-03-01    NaN
#   1949-04-01    NaN
#   1949-05-01    NaN
#   1949-06-01    NaN
#   1949-07-01    0.0
#   1949-08-01    0.0
#   1949-09-01    0.0
#   1949-10-01    0.0
#   1949-11-01    0.0
#   1949-12-01    0.0
#   1950-01-01    0.2
#   Name: year, dtype: float64 timestamp
#                              1949-02-01    NaN
#                              1949-03-01    NaN
#                              1949-04-01    NaN
#                              1949-05-01    NaN
#                              1949-06-01    NaN
#                              1949-07-01    1.0
#                              1949-08-01    1.0
#                              1949-09-01    1.0
#                              1949-10-01    1.0
#                              1949-11-01    1.0
#                              1949-12-01    1.0
#                              1950-01-01   -1.4
#                              Name: month, dtype: float64
#   timestamp
#   1949-02-01    NaN
#   1949-03-01    NaN
#   1949-04-01    NaN
#   1949-05-01    NaN
#   1949-06-01    NaN
#   1949-07-01    8.8
#   1949-08-01    5.8
#   1949-09-01    4.6
#   1949-10-01    1.6
#   1949-11-01   -7.0
#   1949-12-01   -6.0
#   1950-01-01   -5.0
#   Name: target, dtype: float64]
#  [127.58333333333333 1949.1666666666667 6.5 ...
#   timestamp
#   1949-03-01    NaN
#   1949-04-01    NaN
#   1949-05-01    NaN
#   1949-06-01    NaN
#   1949-07-01    NaN
#   1949-08-01    0.0
#   1949-09-01    0.0
#   1949-10-01    0.0
#   1949-11-01    0.0
#   1949-12-01    0.0
#   1950-01-01    0.2
#   1950-02-01    0.2
#   Name: year, dtype: float64 timestamp
#                              1949-03-01    NaN
#                              1949-04-01    NaN
#                              1949-05-01    NaN
#                              1949-06-01    NaN
#                              1949-07-01    NaN
#                              1949-08-01    1.0
#                              1949-09-01    1.0
#                              1949-10-01    1.0
#                              1949-11-01    1.0
#                              1949-12-01    1.0
#                              1950-01-01   -1.4
#                              1950-02-01   -1.4
#                              Name: month, dtype: float64
#   timestamp
#   1949-03-01    NaN
#   1949-04-01    NaN
#   1949-05-01    NaN
#   1949-06-01    NaN
#   1949-07-01    NaN
#   1949-08-01    5.8
#   1949-09-01    4.6
#   1949-10-01    1.6
#   1949-11-01   -7.0
#   1949-12-01   -6.0
#   1950-01-01   -5.0
#   1950-02-01   -1.6
#   Name: target, dtype: float64]
#  ...
#  [418.3333333333333 1958.8333333333333 6.5 ... timestamp
#                                                1958-11-01    NaN
#                                                1958-12-01    NaN
#                                                1959-01-01    NaN
#                                                1959-02-01    NaN
#                                                1959-03-01    NaN
#                                                1959-04-01    0.2
#                                                1959-05-01    0.2
#                                                1959-06-01    0.0
#                                                1959-07-01    0.0
#                                                1959-08-01    0.0
#                                                1959-09-01    0.0
#                                                1959-10-01    0.0
#                                                Name: year, dtype: float64
#   timestamp
#   1958-11-01    NaN
#   1958-12-01    NaN
#   1959-01-01    NaN
#   1959-02-01    NaN
#   1959-03-01    NaN
#   1959-04-01   -1.4
#   1959-05-01   -1.4
#   1959-06-01    1.0
#   1959-07-01    1.0
#   1959-08-01    1.0
#   1959-09-01    1.0
#   1959-10-01    1.0
#   Name: month, dtype: float64 timestamp
#                               1958-11-01     NaN
#                               1958-12-01     NaN
#                               1959-01-01     NaN
#                               1959-02-01     NaN
#                               1959-03-01     NaN
#                               1959-04-01    19.8
#                               1959-05-01    13.4
#                               1959-06-01    23.6
#                               1959-07-01    46.2
#                               1959-08-01    37.4
#                               1959-09-01     9.4
#                               1959-10-01    -2.2
#                               Name: target, dtype: float64]
#  [422.6666666666667 1958.9166666666667 6.5 ... timestamp
#                                                1958-12-01    NaN
#                                                1959-01-01    NaN
#                                                1959-02-01    NaN
#                                                1959-03-01    NaN
#                                                1959-04-01    NaN
#                                                1959-05-01    0.2
#                                                1959-06-01    0.0
#                                                1959-07-01    0.0
#                                                1959-08-01    0.0
#                                                1959-09-01    0.0
#                                                1959-10-01    0.0
#                                                1959-11-01    0.0
#                                                Name: year, dtype: float64
#   timestamp
#   1958-12-01    NaN
#   1959-01-01    NaN
#   1959-02-01    NaN
#   1959-03-01    NaN
#   1959-04-01    NaN
#   1959-05-01   -1.4
#   1959-06-01    1.0
#   1959-07-01    1.0
#   1959-08-01    1.0
#   1959-09-01    1.0
#   1959-10-01    1.0
#   1959-11-01    1.0
#   Name: month, dtype: float64 timestamp
#                               1958-12-01     NaN
#                               1959-01-01     NaN
#                               1959-02-01     NaN
#                               1959-03-01     NaN
#                               1959-04-01     NaN
#                               1959-05-01    13.4
#                               1959-06-01    23.6
#                               1959-07-01    46.2
#                               1959-08-01    37.4
#                               1959-09-01     9.4
#                               1959-10-01    -2.2
#                               1959-11-01   -29.0
#                               Name: target, dtype: float64]
#  [428.3333333333333 1959.0 6.5 ... timestamp
#                                    1959-01-01    NaN
#                                    1959-02-01    NaN
#                                    1959-03-01    NaN
#                                    1959-04-01    NaN
#                                    1959-05-01    NaN
#                                    1959-06-01    0.0
#                                    1959-07-01    0.0
#                                    1959-08-01    0.0
#                                    1959-09-01    0.0
#                                    1959-10-01    0.0
#                                    1959-11-01    0.0
#                                    1959-12-01    0.0
#                                    Name: year, dtype: float64
#   timestamp
#   1959-01-01    NaN
#   1959-02-01    NaN
#   1959-03-01    NaN
#   1959-04-01    NaN
#   1959-05-01    NaN
#   1959-06-01    1.0
#   1959-07-01    1.0
#   1959-08-01    1.0
#   1959-09-01    1.0
#   1959-10-01    1.0
#   1959-11-01    1.0
#   1959-12-01    1.0
#   Name: month, dtype: float64 timestamp
#                               1959-01-01     NaN
#                               1959-02-01     NaN
#                               1959-03-01     NaN
#                               1959-04-01     NaN
#                               1959-05-01     NaN
#                               1959-06-01    23.6
#                               1959-07-01    46.2
#                               1959-08-01    37.4
#                               1959-09-01     9.4
#                               1959-10-01    -2.2
#                               1959-11-01   -29.0
#                               1959-12-01   -38.0
#                               Name: target, dtype: float64]]

# %%
# Type od data in extracted_features_flattened
for col_idx in range(extracted_features_flattened.shape[1]):
    unique_types = set(type(val) for val in extracted_features_flattened[:, col_idx])
    print(f"Column {col_idx} types: {unique_types}")
# Out:
# Column 0 types: {<class 'float'>}
# Column 1 types: {<class 'float'>}
# Column 2 types: {<class 'float'>}
# Column 3 types: {<class 'float'>}
# Column 4 types: {<class 'float'>}
# Column 5 types: {<class 'float'>}
# Column 6 types: {<class 'float'>}
# Column 7 types: {<class 'float'>}
# Column 8 types: {<class 'float'>}
# Column 9 types: {<class 'float'>}
# Column 10 types: {<class 'float'>}
# Column 11 types: {<class 'float'>}
# Column 12 types: {<class 'float'>}
# Column 13 types: {<class 'int'>, <class 'float'>}
# Column 14 types: {<class 'float'>}
# Column 15 types: {<class 'float'>}
# Column 16 types: {<class 'float'>}
# Column 17 types: {<class 'float'>}
# Column 18 types: {<class 'float'>}
# Column 19 types: {<class 'float'>}
# Column 20 types: {<class 'float'>}
# Column 21 types: {<class 'float'>}
# Column 22 types: {<class 'float'>}
# Column 23 types: {<class 'float'>}
# Column 24 types: {<class 'float'>}
# Column 25 types: {<class 'float'>}
# Column 26 types: {<class 'float'>}
# Column 27 types: {<class 'float'>}
# Column 28 types: {<class 'float'>}
# Column 29 types: {<class 'int'>}
# Column 30 types: {<class 'int'>}
# Column 31 types: {<class 'float'>}
# Column 32 types: {<class 'pandas.core.series.Series'>}
# Column 33 types: {<class 'pandas.core.series.Series'>}
# Column 34 types: {<class 'pandas.core.series.Series'>}
# Column 35 types: {<class 'pandas.core.series.Series'>}

# %%
# Coversion nummber
for col_idx in range(extracted_features_flattened.shape[1]):
    try:
        extracted_features_flattened[:, col_idx] = extracted_features_flattened[:, col_idx].astype(float)
    except ValueError:
        print(f"Cannot convert column {col_idx} to float")
# Out:
# Cannot convert column 32 to float
# Cannot convert column 33 to float
# Cannot convert column 34 to float
# Cannot convert column 35 to float

# %%
# Data in sequences
for idx, sequence in enumerate(sequences):
    print(f"Sequence {idx} info:")
    print(sequence.info())
# Out:
# Sequence 0 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1949-01-01 to 1949-12-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 1 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1949-02-01 to 1950-01-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 2 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1949-03-01 to 1950-02-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 3 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1949-04-01 to 1950-03-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 4 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1949-05-01 to 1950-04-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 5 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1949-06-01 to 1950-05-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 6 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1949-07-01 to 1950-06-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 7 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1949-08-01 to 1950-07-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 8 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1949-09-01 to 1950-08-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 9 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1949-10-01 to 1950-09-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 10 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1949-11-01 to 1950-10-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 11 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1949-12-01 to 1950-11-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 12 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1950-01-01 to 1950-12-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 13 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1950-02-01 to 1951-01-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 14 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1950-03-01 to 1951-02-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 15 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1950-04-01 to 1951-03-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 16 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1950-05-01 to 1951-04-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 17 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1950-06-01 to 1951-05-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 18 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1950-07-01 to 1951-06-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 19 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1950-08-01 to 1951-07-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 20 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1950-09-01 to 1951-08-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 21 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1950-10-01 to 1951-09-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 22 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1950-11-01 to 1951-10-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 23 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1950-12-01 to 1951-11-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 24 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1951-01-01 to 1951-12-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 25 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1951-02-01 to 1952-01-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 26 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1951-03-01 to 1952-02-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 27 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1951-04-01 to 1952-03-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 28 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1951-05-01 to 1952-04-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 29 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1951-06-01 to 1952-05-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 30 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1951-07-01 to 1952-06-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 31 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1951-08-01 to 1952-07-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 32 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1951-09-01 to 1952-08-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 33 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1951-10-01 to 1952-09-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 34 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1951-11-01 to 1952-10-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 35 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1951-12-01 to 1952-11-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 36 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1952-01-01 to 1952-12-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 37 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1952-02-01 to 1953-01-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 38 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1952-03-01 to 1953-02-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 39 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1952-04-01 to 1953-03-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 40 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1952-05-01 to 1953-04-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 41 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1952-06-01 to 1953-05-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 42 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1952-07-01 to 1953-06-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 43 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1952-08-01 to 1953-07-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 44 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1952-09-01 to 1953-08-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 45 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1952-10-01 to 1953-09-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 46 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1952-11-01 to 1953-10-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 47 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1952-12-01 to 1953-11-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 48 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1953-01-01 to 1953-12-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 49 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1953-02-01 to 1954-01-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 50 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1953-03-01 to 1954-02-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 51 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1953-04-01 to 1954-03-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 52 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1953-05-01 to 1954-04-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 53 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1953-06-01 to 1954-05-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 54 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1953-07-01 to 1954-06-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 55 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1953-08-01 to 1954-07-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 56 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1953-09-01 to 1954-08-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 57 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1953-10-01 to 1954-09-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 58 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1953-11-01 to 1954-10-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 59 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1953-12-01 to 1954-11-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 60 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1954-01-01 to 1954-12-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 61 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1954-02-01 to 1955-01-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 62 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1954-03-01 to 1955-02-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 63 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1954-04-01 to 1955-03-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 64 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1954-05-01 to 1955-04-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 65 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1954-06-01 to 1955-05-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 66 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1954-07-01 to 1955-06-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 67 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1954-08-01 to 1955-07-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 68 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1954-09-01 to 1955-08-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 69 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1954-10-01 to 1955-09-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 70 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1954-11-01 to 1955-10-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 71 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1954-12-01 to 1955-11-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 72 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1955-01-01 to 1955-12-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 73 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1955-02-01 to 1956-01-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 74 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1955-03-01 to 1956-02-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 75 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1955-04-01 to 1956-03-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 76 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1955-05-01 to 1956-04-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 77 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1955-06-01 to 1956-05-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 78 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1955-07-01 to 1956-06-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 79 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1955-08-01 to 1956-07-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 80 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1955-09-01 to 1956-08-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 81 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1955-10-01 to 1956-09-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 82 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1955-11-01 to 1956-10-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 83 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1955-12-01 to 1956-11-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 84 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1956-01-01 to 1956-12-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 85 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1956-02-01 to 1957-01-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 86 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1956-03-01 to 1957-02-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 87 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1956-04-01 to 1957-03-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 88 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1956-05-01 to 1957-04-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 89 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1956-06-01 to 1957-05-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 90 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1956-07-01 to 1957-06-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 91 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1956-08-01 to 1957-07-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 92 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1956-09-01 to 1957-08-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 93 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1956-10-01 to 1957-09-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 94 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1956-11-01 to 1957-10-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 95 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1956-12-01 to 1957-11-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 96 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1957-01-01 to 1957-12-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 97 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1957-02-01 to 1958-01-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 98 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1957-03-01 to 1958-02-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 99 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1957-04-01 to 1958-03-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 100 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1957-05-01 to 1958-04-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 101 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1957-06-01 to 1958-05-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 102 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1957-07-01 to 1958-06-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 103 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1957-08-01 to 1958-07-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 104 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1957-09-01 to 1958-08-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 105 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1957-10-01 to 1958-09-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 106 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1957-11-01 to 1958-10-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 107 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1957-12-01 to 1958-11-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 108 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1958-01-01 to 1958-12-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 109 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1958-02-01 to 1959-01-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 110 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1958-03-01 to 1959-02-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 111 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1958-04-01 to 1959-03-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 112 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1958-05-01 to 1959-04-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 113 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1958-06-01 to 1959-05-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 114 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1958-07-01 to 1959-06-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 115 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1958-08-01 to 1959-07-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 116 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1958-09-01 to 1959-08-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 117 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1958-10-01 to 1959-09-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 118 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1958-11-01 to 1959-10-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 119 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1958-12-01 to 1959-11-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None
# Sequence 120 info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 1959-01-01 to 1959-12-01
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passengers      12 non-null     float64
#  1   year            12 non-null     int32
#  2   month           12 non-null     int32
#  3   adjusted_month  12 non-null     int32
#  4   target          12 non-null     float64
# dtypes: float64(2), int32(3)
# memory usage: 432.0 bytes
# None

# %%
print(f"Shape of extracted features: {extracted_features_flattened.shape}")
print(f"Sample of extracted features: {extracted_features_flattened[:5]}")
# Out:
# Shape of extracted features: (121, 36)
# Sample of extracted features: [[126.66666666666667 1949.0 6.5 139.66666666666666 188.24242424242428 0.0
#   13.0 363.6969696969697 0.9942904703154525 0.0 0.9978560377849336
#   0.9946432601505386 0.17905526682819217 0.0 0.0 0.3896679151782587
#   0.00040863836742780716 0.0 1.0 0.06376734413728247 0.0 0.0
#   0.506993006993007 0.0 0.11716881874701102 0.0 0.0 0.05965855023789546
#   194604.0 45583212.0 650.0 238082.0 timestamp
#                                      1949-01-01    NaN
#                                      1949-02-01    NaN
#                                      1949-03-01    NaN
#                                      1949-04-01    NaN
#                                      1949-05-01    NaN
#                                      1949-06-01    4.6
#                                      1949-07-01    6.0
#                                      1949-08-01    3.2
#                                      1949-09-01    1.4
#                                      1949-10-01   -0.4
#                                      1949-11-01   -6.2
#                                      1949-12-01   -6.0
#                                      Name: passengers, dtype: float64
#   timestamp
#   1949-01-01    NaN
#   1949-02-01    NaN
#   1949-03-01    NaN
#   1949-04-01    NaN
#   1949-05-01    NaN
#   1949-06-01    0.0
#   1949-07-01    0.0
#   1949-08-01    0.0
#   1949-09-01    0.0
#   1949-10-01    0.0
#   1949-11-01    0.0
#   1949-12-01    0.0
#   Name: year, dtype: float64 timestamp
#                              1949-01-01    NaN
#                              1949-02-01    NaN
#                              1949-03-01    NaN
#                              1949-04-01    NaN
#                              1949-05-01    NaN
#                              1949-06-01    1.0
#                              1949-07-01    1.0
#                              1949-08-01    1.0
#                              1949-09-01    1.0
#                              1949-10-01    1.0
#                              1949-11-01    1.0
#                              1949-12-01    1.0
#                              Name: month, dtype: float64
#   timestamp
#   1949-01-01    NaN
#   1949-02-01    NaN
#   1949-03-01    NaN
#   1949-04-01    NaN
#   1949-05-01    NaN
#   1949-06-01    6.8
#   1949-07-01    8.8
#   1949-08-01    5.8
#   1949-09-01    4.6
#   1949-10-01    1.6
#   1949-11-01   -7.0
#   1949-12-01   -6.0
#   Name: target, dtype: float64]
#  [126.91666666666667 1949.0833333333333 6.5 142.16666666666666
#   180.99242424242422 0.08333333333333333 13.0 304.1515151515151
#   0.9929767252977294 0.8411056053664362 0.9978560377849336
#   0.9924306615788326 0.19321945397425233 3.4641016151386994 0.0
#   0.301399619684421 0.10210797113814986 0.23076923076923078
#   0.28994082840236685 0.0075246065083666 0.08738995158567377 0.0
#   0.19930069930069924 0.0 0.09493863166848948 0.2499999999999999 0.25
#   0.01831816360409877 195285.0 45587111.0 650.0 245882.0
#   timestamp
#   1949-02-01    NaN
#   1949-03-01    NaN
#   1949-04-01    NaN
#   1949-05-01    NaN
#   1949-06-01    NaN
#   1949-07-01    6.0
#   1949-08-01    3.2
#   1949-09-01    1.4
#   1949-10-01   -0.4
#   1949-11-01   -6.2
#   1949-12-01   -6.0
#   1950-01-01   -6.6
#   Name: passengers, dtype: float64 timestamp
#                                    1949-02-01    NaN
#                                    1949-03-01    NaN
#                                    1949-04-01    NaN
#                                    1949-05-01    NaN
#                                    1949-06-01    NaN
#                                    1949-07-01    0.0
#                                    1949-08-01    0.0
#                                    1949-09-01    0.0
#                                    1949-10-01    0.0
#                                    1949-11-01    0.0
#                                    1949-12-01    0.0
#                                    1950-01-01    0.2
#                                    Name: year, dtype: float64
#   timestamp
#   1949-02-01    NaN
#   1949-03-01    NaN
#   1949-04-01    NaN
#   1949-05-01    NaN
#   1949-06-01    NaN
#   1949-07-01    1.0
#   1949-08-01    1.0
#   1949-09-01    1.0
#   1949-10-01    1.0
#   1949-11-01    1.0
#   1949-12-01    1.0
#   1950-01-01   -1.4
#   Name: month, dtype: float64 timestamp
#                               1949-02-01    NaN
#                               1949-03-01    NaN
#                               1949-04-01    NaN
#                               1949-05-01    NaN
#                               1949-06-01    NaN
#                               1949-07-01    8.8
#                               1949-08-01    5.8
#                               1949-09-01    4.6
#                               1949-10-01    1.6
#                               1949-11-01   -7.0
#                               1949-12-01   -6.0
#                               1950-01-01   -5.0
#                               Name: target, dtype: float64]
#  [127.58333333333333 1949.1666666666667 6.5 144.16666666666666
#   173.3560606060606 0.1515151515151515 13.0 281.60606060606057
#   0.9909520591967924 0.9280504173077897 0.9978560377849336
#   0.9897712486994845 0.057521621934225886 2.0552372125857197 0.0
#   0.015677124276230876 0.19994291422862848 0.4195804195804196
#   0.025869235659445447 9.030031627685774e-06 0.10002330696732654 0.0 0.0
#   0.0 0.0018518518518518823 0.16000000000000014 0.16000000000000014
#   0.0007753346659398197 197237.0 45591010.0 650.0 252506.0
#   timestamp
#   1949-03-01    NaN
#   1949-04-01    NaN
#   1949-05-01    NaN
#   1949-06-01    NaN
#   1949-07-01    NaN
#   1949-08-01    3.2
#   1949-09-01    1.4
#   1949-10-01   -0.4
#   1949-11-01   -6.2
#   1949-12-01   -6.0
#   1950-01-01   -6.6
#   1950-02-01   -2.0
#   Name: passengers, dtype: float64 timestamp
#                                    1949-03-01    NaN
#                                    1949-04-01    NaN
#                                    1949-05-01    NaN
#                                    1949-06-01    NaN
#                                    1949-07-01    NaN
#                                    1949-08-01    0.0
#                                    1949-09-01    0.0
#                                    1949-10-01    0.0
#                                    1949-11-01    0.0
#                                    1949-12-01    0.0
#                                    1950-01-01    0.2
#                                    1950-02-01    0.2
#                                    Name: year, dtype: float64
#   timestamp
#   1949-03-01    NaN
#   1949-04-01    NaN
#   1949-05-01    NaN
#   1949-06-01    NaN
#   1949-07-01    NaN
#   1949-08-01    1.0
#   1949-09-01    1.0
#   1949-10-01    1.0
#   1949-11-01    1.0
#   1949-12-01    1.0
#   1950-01-01   -1.4
#   1950-02-01   -1.4
#   Name: month, dtype: float64 timestamp
#                               1949-03-01    NaN
#                               1949-04-01    NaN
#                               1949-05-01    NaN
#                               1949-06-01    NaN
#                               1949-07-01    NaN
#                               1949-08-01    5.8
#                               1949-09-01    4.6
#                               1949-10-01    1.6
#                               1949-11-01   -7.0
#                               1949-12-01   -6.0
#                               1950-01-01   -5.0
#                               1950-02-01   -1.6
#                               Name: target, dtype: float64]
#  [128.33333333333334 1949.25 6.5 147.25 187.33333333333337
#   0.20454545454545456 13.0 374.3863636363636 0.9939142687685141
#   0.966266036765902 0.9978560377849336 0.9936145425904099
#   -0.047189027334200884 1.3266499161421599 0.0 0.014970955637163734
#   0.05823697493060158 0.5664335664335663 0.017653674996332337
#   0.04539277877467643 0.023347352528847218 0.27777777777777773
#   0.045454545454545435 0.0 0.03580619894819281 0.09000000000000041
#   0.0900000000000003 0.031209787729874816 199694.0 45594909.0 650.0
#   264309.0 timestamp
#            1949-04-01    NaN
#            1949-05-01    NaN
#            1949-06-01    NaN
#            1949-07-01    NaN
#            1949-08-01    NaN
#            1949-09-01    1.4
#            1949-10-01   -0.4
#            1949-11-01   -6.2
#            1949-12-01   -6.0
#            1950-01-01   -6.6
#            1950-02-01   -2.0
#            1950-03-01    4.4
#            Name: passengers, dtype: float64 timestamp
#                                             1949-04-01    NaN
#                                             1949-05-01    NaN
#                                             1949-06-01    NaN
#                                             1949-07-01    NaN
#                                             1949-08-01    NaN
#                                             1949-09-01    0.0
#                                             1949-10-01    0.0
#                                             1949-11-01    0.0
#                                             1949-12-01    0.0
#                                             1950-01-01    0.2
#                                             1950-02-01    0.2
#                                             1950-03-01    0.2
#                                             Name: year, dtype: float64
#   timestamp
#   1949-04-01    NaN
#   1949-05-01    NaN
#   1949-06-01    NaN
#   1949-07-01    NaN
#   1949-08-01    NaN
#   1949-09-01    1.0
#   1949-10-01    1.0
#   1949-11-01    1.0
#   1949-12-01    1.0
#   1950-01-01   -1.4
#   1950-02-01   -1.4
#   1950-03-01   -1.4
#   Name: month, dtype: float64 timestamp
#                               1949-04-01    NaN
#                               1949-05-01    NaN
#                               1949-06-01    NaN
#                               1949-07-01    NaN
#                               1949-08-01    NaN
#                               1949-09-01    4.6
#                               1949-10-01    1.6
#                               1949-11-01   -7.0
#                               1949-12-01   -6.0
#                               1950-01-01   -5.0
#                               1950-02-01   -1.6
#                               1950-03-01    9.0
#                               Name: target, dtype: float64]
#  [128.83333333333334 1949.3333333333333 6.5 149.58333333333334
#   191.06060606060603 0.2424242424242424 13.0 377.3560606060606
#   0.9945438734545614 0.9847638347531571 0.9978560377849336
#   0.9925823440216783 -0.16387254508369822 0.8124038404641503 0.0
#   -0.3343910974981669 0.02695163678510229 0.6713286713286711
#   0.11741405447699153 0.04897435382669567 0.016151202749140895
#   0.4166666666666477 0.1153846153846154 0.0 0.0005709717939931247
#   0.04000000000000048 0.04000000000000037 0.010880314120897738 201278.0
#   45598808.0 650.0 272653.0 timestamp
#                             1949-05-01    NaN
#                             1949-06-01    NaN
#                             1949-07-01    NaN
#                             1949-08-01    NaN
#                             1949-09-01    NaN
#                             1949-10-01   -0.4
#                             1949-11-01   -6.2
#                             1949-12-01   -6.0
#                             1950-01-01   -6.6
#                             1950-02-01   -2.0
#                             1950-03-01    4.4
#                             1950-04-01    6.2
#                             Name: passengers, dtype: float64
#   timestamp
#   1949-05-01    NaN
#   1949-06-01    NaN
#   1949-07-01    NaN
#   1949-08-01    NaN
#   1949-09-01    NaN
#   1949-10-01    0.0
#   1949-11-01    0.0
#   1949-12-01    0.0
#   1950-01-01    0.2
#   1950-02-01    0.2
#   1950-03-01    0.2
#   1950-04-01    0.2
#   Name: year, dtype: float64 timestamp
#                              1949-05-01    NaN
#                              1949-06-01    NaN
#                              1949-07-01    NaN
#                              1949-08-01    NaN
#                              1949-09-01    NaN
#                              1949-10-01    1.0
#                              1949-11-01    1.0
#                              1949-12-01    1.0
#                              1950-01-01   -1.4
#                              1950-02-01   -1.4
#                              1950-03-01   -1.4
#                              1950-04-01   -1.4
#                              Name: month, dtype: float64
#   timestamp
#   1949-05-01    NaN
#   1949-06-01    NaN
#   1949-07-01    NaN
#   1949-08-01    NaN
#   1949-09-01    NaN
#   1949-10-01    1.6
#   1949-11-01   -7.0
#   1949-12-01   -6.0
#   1950-01-01   -5.0
#   1950-02-01   -1.6
#   1950-03-01    9.0
#   1950-04-01    9.8
#   Name: target, dtype: float64]]

# %%
# Sprawdź dane i konwertuj kolumny do float, jeśli możliwe
cleaned_features = []
for col_idx in range(extracted_features_flattened.shape[1]):
    try:
        column = extracted_features_flattened[:, col_idx].astype(float)
        cleaned_features.append(column)
    except ValueError:
        print(f"Skipping column {col_idx} due to non-numeric values")

# Przekształć do numpy array i stwórz DataFrame
cleaned_features = np.array(cleaned_features).T  # Transpozycja, aby uzyskać poprawny kształt
feature_columns = [f"feature_{i}" for i in range(cleaned_features.shape[1])]

# Utwórz DataFrame
features_cleaned = pd.DataFrame(cleaned_features, columns=feature_columns)

# Zweryfikuj wyniki
print(features_cleaned.head())
# Out:
# Skipping column 32 due to non-numeric values
# Skipping column 33 due to non-numeric values
# Skipping column 34 due to non-numeric values
# Skipping column 35 due to non-numeric values
#     feature_0    feature_1  feature_2   feature_3   feature_4  feature_5  \
# 0  126.666667  1949.000000        6.5  139.666667  188.242424   0.000000
# 1  126.916667  1949.083333        6.5  142.166667  180.992424   0.083333
# 2  127.583333  1949.166667        6.5  144.166667  173.356061   0.151515
# 3  128.333333  1949.250000        6.5  147.250000  187.333333   0.204545
# 4  128.833333  1949.333333        6.5  149.583333  191.060606   0.242424
#
#    feature_6   feature_7  feature_8  feature_9  ...  feature_22  feature_23  \
# 0       13.0  363.696970   0.994290   0.000000  ...    0.506993         0.0
# 1       13.0  304.151515   0.992977   0.841106  ...    0.199301         0.0
# 2       13.0  281.606061   0.990952   0.928050  ...    0.000000         0.0
# 3       13.0  374.386364   0.993914   0.966266  ...    0.045455         0.0
# 4       13.0  377.356061   0.994544   0.984764  ...    0.115385         0.0
#
#    feature_24  feature_25  feature_26  feature_27  feature_28  feature_29  \
# 0    0.117169        0.00        0.00    0.059659    194604.0  45583212.0
# 1    0.094939        0.25        0.25    0.018318    195285.0  45587111.0
# 2    0.001852        0.16        0.16    0.000775    197237.0  45591010.0
# 3    0.035806        0.09        0.09    0.031210    199694.0  45594909.0
# 4    0.000571        0.04        0.04    0.010880    201278.0  45598808.0
#
#    feature_30  feature_31
# 0       650.0    238082.0
# 1       650.0    245882.0
# 2       650.0    252506.0
# 3       650.0    264309.0
# 4       650.0    272653.0
#
# [5 rows x 32 columns]

# %%
print(f"Number of features in extractor: {len(extractor.features)}")
print(f"Number of columns in extracted_features_flattened: {extracted_features_flattened.shape[1]}")
# Out:
# Number of features in extractor: 9
# Number of columns in extracted_features_flattened: 36

# %%
feature_columns = [f"feature_{i}" for i in range(extracted_features_flattened.shape[1])]

# %%
features = pd.DataFrame(extracted_features_flattened, columns=feature_columns)

# %%
print(features.shape)
print(features.head())
# Out:
# (121, 36)
#     feature_0    feature_1 feature_2   feature_3   feature_4 feature_5  \
# 0  126.666667       1949.0       6.5  139.666667  188.242424       0.0
# 1  126.916667  1949.083333       6.5  142.166667  180.992424  0.083333
# 2  127.583333  1949.166667       6.5  144.166667  173.356061  0.151515
# 3  128.333333      1949.25       6.5      147.25  187.333333  0.204545
# 4  128.833333  1949.333333       6.5  149.583333  191.060606  0.242424
#
#   feature_6   feature_7 feature_8 feature_9  ... feature_26 feature_27  \
# 0      13.0   363.69697   0.99429       0.0  ...        0.0   0.059659
# 1      13.0  304.151515  0.992977  0.841106  ...       0.25   0.018318
# 2      13.0  281.606061  0.990952   0.92805  ...       0.16   0.000775
# 3      13.0  374.386364  0.993914  0.966266  ...       0.09    0.03121
# 4      13.0  377.356061  0.994544  0.984764  ...       0.04    0.01088
#
#   feature_28  feature_29 feature_30 feature_31  \
# 0   194604.0  45583212.0      650.0   238082.0
# 1   195285.0  45587111.0      650.0   245882.0
# 2   197237.0  45591010.0      650.0   252506.0
# 3   199694.0  45594909.0      650.0   264309.0
# 4   201278.0  45598808.0      650.0   272653.0
#
#                                           feature_32  \
# 0  timestamp
# 1949-01-01    NaN
# 1949-02-01    NaN
# ...
# 1  timestamp
# 1949-02-01    NaN
# 1949-03-01    NaN
# ...
# 2  timestamp
# 1949-03-01    NaN
# 1949-04-01    NaN
# ...
# 3  timestamp
# 1949-04-01    NaN
# 1949-05-01    NaN
# ...
# 4  timestamp
# 1949-05-01    NaN
# 1949-06-01    NaN
# ...
#
#                                           feature_33  \
# 0  timestamp
# 1949-01-01    NaN
# 1949-02-01    NaN
# ...
# 1  timestamp
# 1949-02-01    NaN
# 1949-03-01    NaN
# ...
# 2  timestamp
# 1949-03-01    NaN
# 1949-04-01    NaN
# ...
# 3  timestamp
# 1949-04-01    NaN
# 1949-05-01    NaN
# ...
# 4  timestamp
# 1949-05-01    NaN
# 1949-06-01    NaN
# ...
#
#                                           feature_34  \
# 0  timestamp
# 1949-01-01    NaN
# 1949-02-01    NaN
# ...
# 1  timestamp
# 1949-02-01    NaN
# 1949-03-01    NaN
# ...
# 2  timestamp
# 1949-03-01    NaN
# 1949-04-01    NaN
# ...
# 3  timestamp
# 1949-04-01    NaN
# 1949-05-01    NaN
# ...
# 4  timestamp
# 1949-05-01    NaN
# 1949-06-01    NaN
# ...
#
#                                           feature_35
# 0  timestamp
# 1949-01-01    NaN
# 1949-02-01    NaN
# ...
# 1  timestamp
# 1949-02-01    NaN
# 1949-03-01    NaN
# ...
# 2  timestamp
# 1949-03-01    NaN
# 1949-04-01    NaN
# ...
# 3  timestamp
# 1949-04-01    NaN
# 1949-05-01    NaN
# ...
# 4  timestamp
# 1949-05-01    NaN
# 1949-06-01    NaN
# ...
#
# [5 rows x 36 columns]

# %%
# Zweryfikuj liczby cech
print(f"Number of features in extractor: {len(extractor.features)}")
print(f"Number of columns in extracted_features_flattened: {extracted_features_flattened.shape[1]}")

# Stwórz dynamiczne nazwy kolumn: cecha + indeks
feature_columns = []
for feature in extractor.features:
    feature_columns.extend([f"{feature}_part_{i}" for i in range(extracted_features_flattened.shape[1] // len(extractor.features))])

# Zweryfikuj długość nazw kolumn
print(f"Number of generated column names: {len(feature_columns)}")

# Upewnij się, że liczba kolumn zgadza się z danymi
if len(feature_columns) != extracted_features_flattened.shape[1]:
    raise ValueError("Mismatch between number of feature columns and extracted data dimensions!")

# Tworzenie DataFrame
features = pd.DataFrame(extracted_features_flattened, columns=feature_columns)

# Weryfikacja wyników
print(features.head())
# Out:
# Number of features in extractor: 9
# Number of columns in extracted_features_flattened: 36
# Number of generated column names: 36
#   mean_part_0  mean_part_1 mean_part_2 mean_part_3 variance_part_0  \
# 0  126.666667       1949.0         6.5  139.666667      188.242424
# 1  126.916667  1949.083333         6.5  142.166667      180.992424
# 2  127.583333  1949.166667         6.5  144.166667      173.356061
# 3  128.333333      1949.25         6.5      147.25      187.333333
# 4  128.833333  1949.333333         6.5  149.583333      191.060606
#
#   variance_part_1 variance_part_2 variance_part_3 entropy_part_0  \
# 0             0.0            13.0       363.69697        0.99429
# 1        0.083333            13.0      304.151515       0.992977
# 2        0.151515            13.0      281.606061       0.990952
# 3        0.204545            13.0      374.386364       0.993914
# 4        0.242424            13.0      377.356061       0.994544
#
#   entropy_part_1  ... linearity_part_2 linearity_part_3  \
# 0            0.0  ...              0.0         0.059659
# 1       0.841106  ...             0.25         0.018318
# 2        0.92805  ...             0.16         0.000775
# 3       0.966266  ...             0.09          0.03121
# 4       0.984764  ...             0.04          0.01088
#
#   absolute_energy_part_0 absolute_energy_part_1 absolute_energy_part_2  \
# 0               194604.0             45583212.0                  650.0
# 1               195285.0             45587111.0                  650.0
# 2               197237.0             45591010.0                  650.0
# 3               199694.0             45594909.0                  650.0
# 4               201278.0             45598808.0                  650.0
#
#   absolute_energy_part_3                                 mean_change_part_0  \
# 0               238082.0  timestamp
# 1949-01-01    NaN
# 1949-02-01    NaN
# ...
# 1               245882.0  timestamp
# 1949-02-01    NaN
# 1949-03-01    NaN
# ...
# 2               252506.0  timestamp
# 1949-03-01    NaN
# 1949-04-01    NaN
# ...
# 3               264309.0  timestamp
# 1949-04-01    NaN
# 1949-05-01    NaN
# ...
# 4               272653.0  timestamp
# 1949-05-01    NaN
# 1949-06-01    NaN
# ...
#
#                                   mean_change_part_1  \
# 0  timestamp
# 1949-01-01    NaN
# 1949-02-01    NaN
# ...
# 1  timestamp
# 1949-02-01    NaN
# 1949-03-01    NaN
# ...
# 2  timestamp
# 1949-03-01    NaN
# 1949-04-01    NaN
# ...
# 3  timestamp
# 1949-04-01    NaN
# 1949-05-01    NaN
# ...
# 4  timestamp
# 1949-05-01    NaN
# 1949-06-01    NaN
# ...
#
#                                   mean_change_part_2  \
# 0  timestamp
# 1949-01-01    NaN
# 1949-02-01    NaN
# ...
# 1  timestamp
# 1949-02-01    NaN
# 1949-03-01    NaN
# ...
# 2  timestamp
# 1949-03-01    NaN
# 1949-04-01    NaN
# ...
# 3  timestamp
# 1949-04-01    NaN
# 1949-05-01    NaN
# ...
# 4  timestamp
# 1949-05-01    NaN
# 1949-06-01    NaN
# ...
#
#                                   mean_change_part_3
# 0  timestamp
# 1949-01-01    NaN
# 1949-02-01    NaN
# ...
# 1  timestamp
# 1949-02-01    NaN
# 1949-03-01    NaN
# ...
# 2  timestamp
# 1949-03-01    NaN
# 1949-04-01    NaN
# ...
# 3  timestamp
# 1949-04-01    NaN
# 1949-05-01    NaN
# ...
# 4  timestamp
# 1949-05-01    NaN
# 1949-06-01    NaN
# ...
#
# [5 rows x 36 columns]

# %%
# Generate column names dynamically based on the extracted features
feature_columns = [f"{features}_series" for features in extractor.features]
features = pd.DataFrame(extracted_features_flattened, columns=feature_columns)

# Verify results
print(features.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 3
#       1 # Generate column names dynamically based on the extracted features
#       2 feature_columns = [f"{features}_series" for features in extractor.features]
# ----> 3 features = pd.DataFrame(extracted_features_flattened, columns=feature_columns)
#       5 # Verify results
#       6 print(features.head())
#
# File d:\pbl\InterpreTS\env\lib\site-packages\pandas\core\frame.py:758, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     747         mgr = dict_to_mgr(
#     748             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     749             # attribute "name"
#    (...)
#     755             copy=_copy,
#     756         )
#     757     else:
# --> 758         mgr = ndarray_to_mgr(
#     759             data,
#     760             index,
#     761             columns,
#     762             dtype=dtype,
#     763             copy=copy,
#     764             typ=manager,
#     765         )
#     767 # For data is list-like, or Iterable (will consume into list)
#     768 elif is_list_like(data):
#
# File d:\pbl\InterpreTS\env\lib\site-packages\pandas\core\internals\construction.py:337, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     332 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     333 index, columns = _get_axes(
#     334     values.shape[0], values.shape[1], index=index, columns=columns
#     335 )
# --> 337 _check_values_indices_shape_match(values, index, columns)
#     339 if typ == "array":
#     340     if issubclass(values.dtype.type, str):
#
# File d:\pbl\InterpreTS\env\lib\site-packages\pandas\core\internals\construction.py:408, in _check_values_indices_shape_match(values, index, columns)
#     406 passed = values.shape
#     407 implied = (len(index), len(columns))
# --> 408 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (121, 36), indices imply (121, 9)

# %%
for start_idx in range(len(data) - window_size + 1):
    window = data.iloc[start_idx:start_idx + window_size].copy()
    sequences.append(window)

# %%
# Initialize models
models = {
    "Linear Regression": LinearRegression(),
    "Random Forest": RandomForestRegressor(random_state=42),
    "Support Vector Regression": SVR(kernel="rbf"),
    "XGBoost": XGBRegressor(random_state=42),
}

# %%
# Fit models and evaluate
results = {}
for model_name, model in models.items():
    print(f"Training {model_name}...")
    model.fit(features_train, train_y)
    predictions = model.predict(features_test)

    rmse = np.sqrt(mean_squared_error(test_y, predictions))
    results[model_name] = rmse
    print(f"{model_name} RMSE: {rmse:.4f}\n")
# Out:
# Training Linear Regression...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[137], line 5
#       3 for model_name, model in models.items():
#       4     print(f"Training {model_name}...")
# ----> 5     model.fit(features_train, train_y)
#       6     predictions = model.predict(features_test)
#       8     rmse = np.sqrt(mean_squared_error(test_y, predictions))
#
# File d:\pbl\InterpreTS\env\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File d:\pbl\InterpreTS\env\lib\site-packages\sklearn\linear_model\_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
#     676 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 678 X, y = self._validate_data(
#     679     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     680 )
#     682 has_sw = sample_weight is not None
#     683 if has_sw:
#
# File d:\pbl\InterpreTS\env\lib\site-packages\sklearn\base.py:622, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     620         y = check_array(y, input_name="y", **check_y_params)
#     621     else:
# --> 622         X, y = check_X_y(X, y, **check_params)
#     623     out = X, y
#     625 if not no_val_X and check_params.get("ensure_2d", True):
#
# File d:\pbl\InterpreTS\env\lib\site-packages\sklearn\utils\validation.py:1146, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1141         estimator_name = _check_estimator_name(estimator)
#    1142     raise ValueError(
#    1143         f"{estimator_name} requires y to be passed, but the target y is None"
#    1144     )
# -> 1146 X = check_array(
#    1147     X,
#    1148     accept_sparse=accept_sparse,
#    1149     accept_large_sparse=accept_large_sparse,
#    1150     dtype=dtype,
#    1151     order=order,
#    1152     copy=copy,
#    1153     force_all_finite=force_all_finite,
#    1154     ensure_2d=ensure_2d,
#    1155     allow_nd=allow_nd,
#    1156     ensure_min_samples=ensure_min_samples,
#    1157     ensure_min_features=ensure_min_features,
#    1158     estimator=estimator,
#    1159     input_name="X",
#    1160 )
#    1162 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1164 check_consistent_length(X, y)
#
# File d:\pbl\InterpreTS\env\lib\site-packages\sklearn\utils\validation.py:967, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     965     n_samples = _num_samples(array)
#     966     if n_samples < ensure_min_samples:
# --> 967         raise ValueError(
#     968             "Found array with %d sample(s) (shape=%s) while a"
#     969             " minimum of %d is required%s."
#     970             % (n_samples, array.shape, ensure_min_samples, context)
#     971         )
#     973 if ensure_min_features > 0 and array.ndim == 2:
#     974     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 5)) while a minimum of 1 is required by LinearRegression.

# %%
# Display RMSE results
print("Model Performance (RMSE):")
for model, rmse in results.items():
    print(f"{model}: {rmse:.4f}")

# %%
# Plot predictions from the best model (lowest RMSE)
best_model_name = min(results, key=results.get)
print(f"Best Model: {best_model_name}")

best_model = models[best_model_name]
best_predictions = best_model.predict(features_test)

plt.figure(figsize=(14, 7))
plt.plot(data.index, data["rolling_avg_12"], label="True Values", alpha=0.7)
plt.plot(test_data["timestamp"], best_predictions, label=f"Predicted ({best_model_name})", alpha=0.7)
plt.xlabel("Time")
plt.ylabel("Passengers")
plt.title("True vs Predicted Values")
plt.legend()
plt.show()
